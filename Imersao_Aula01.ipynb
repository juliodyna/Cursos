# %% [markdown]
# #Introdução
# Acesso a base de dados;
# unique();
# value_counts();

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
#5 primeiras linhas
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Número de linhas e colunas
dados.shape
# Out:
# (23814, 877)

# %%
#Ver apenas coluna tratamento
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
#Mostra os valores únicos(sem os repetidos) 
#Podemos ver que tratamento possui apenas dois tipos: com_droga e com_controle
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
#Tempo provavelmente em horas
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
#Os nomes das drogas foram preservados para a análise
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
#Número de itens da coluna droga
len(dados['droga'].unique())
# Out:
# 3289

# %%
#Soma os valores únicos e mostra o total de cada um
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 6e2b418c3       1
# 861a693e3       1
# 225385f09       1
# 19b95658c       1
# e3fe7b417       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# #Desafio 1
# Investigar por que a classe tratamento é tão desbalanceada

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
#Em tratamento, "com_controle" corresponde a utlização de apenas um nome na coluna "droga" (talvez seja placebo)
consulta_tratamento = dados.query("tratamento=='com_controle'")
consulta_tratamento['droga'].value_counts()
# Out:
# cacb2b860    1866
# Name: droga, dtype: int64

# %% [markdown]
# #Desafio 2
# Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# #Desafio 3:
# Proporção das classes tratamento

# %%
trat = dados['tratamento'].value_counts()
droga = trat[0]/(len(dados['tratamento'])-1)
format(droga,'.2%')
# Out:
# '92.17%'

# %%
trat[1]/(len(dados['tratamento'])-1)
controle = trat[1]/(len(dados['tratamento'])-1)
format(controle, '.2%')
# Out:
# '7.84%'

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts(normalize = True).plot.pie()

# %%
dados['tratamento'].value_counts(normalize = True).plot.bar()

# %% [markdown]
# #Desafio 4
# Quantas tipos de drogas foram investigados

# %%
len(dados['droga'].unique())
# Out:
# 3289

# %% [markdown]
# #Desafio 5
# Procurar na documentação o método query(pandas)

# %%
consulta = dados.query("tratamento=='com_controle' & dose=='D1' & tempo==24")
consulta
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 198    id_021fd592f  com_controle     24   D1  ... -0.5976 -0.0881 -0.1365  0.6223
# 350    id_03c5df6d2  com_controle     24   D1  ...  1.2370  1.0950  0.5384  0.6827
# 384    id_041beba5f  com_controle     24   D1  ...  0.1843 -1.2270  1.4140  0.7247
# 395    id_0435d7193  com_controle     24   D1  ...  0.3252  0.1986  0.2604  0.5067
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23458  id_fc27cf188  com_controle     24   D1  ...  1.0940  0.9792 -0.2448  0.0071
# 23615  id_fdbcfc081  com_controle     24   D1  ... -0.4415 -0.2335  0.6713  0.2514
# 23621  id_fdc4f483b  com_controle     24   D1  ...  0.4541  0.3910 -0.6870  0.9207
# 23625  id_fdcc9fc08  com_controle     24   D1  ...  0.5856  0.2984 -0.6856  0.8951
# ...

# %% [markdown]
# #Desafio 6
# Renomear as colunas tirando o hífen

# %%
dados.columns = dados.columns.str.replace('-','')
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
consulta2 = dados.query("g0 > 1 & tratamento=='com_droga' & dose=='D2'")
consulta2['tempo'].value_counts()
# Out:
# 72    450
# 24    438
# 48    403
# Name: tempo, dtype: int64

# %% [markdown]
# #Desafio 7
# Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
import matplotlib.pyplot as plt
tratamento = dados['tratamento'].value_counts(normalize = True)
mylabels = ['Drogas', 'Controle']
mycolors = ['darkorange', 'cyan']
plt.pie(tratamento, labels=mylabels, colors=mycolors, autopct='%1.1f%%')
plt.title('Tratamento', weight='bold', size=18)
plt.legend(loc='lower left')

# %%
time = dados['tempo'].value_counts()
plt.bar(['48', '72', '24'], time, color='darkred', width=0.5,)
plt.title('Tempo - Horas', weight='bold', size=18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-fff1b1165c65> in <module>()
#       2 plt.bar(['48', '72', '24'], time, color='darkred', width=0.5,)
#       3 plt.title('Tempo - Horas', weight='bold', size=18)
# ----> 4 plt.xlabel(x, fontsize=18)
#
# NameError: name 'x' is not defined

# %% [markdown]
# #Desafio 8
# Resumo do que você aprendeu com os dados

# %%
#A coluna id são as células experimentadas que possuem código de id único
#O tratamento mostra a disparidade entre experimentos com droga e de controle
#O tempo está provavelmente em horas(24, 48 e 72) e com certo equilíbrio entre eles
#Em dose temos D1 e D2 também com pouca diferença entre ambos
#droga são seus nomes que aparecem codificados para não influenciar na análise e com alta variedade (3289)
#As colunas restantes são valores que estão normalizados

# %% [markdown]
# #Tabela filtrada
# g-0

# %%
zero = dados['g-0'] > 0
zero.value_counts()
# Out:
# False    12045
# True     11769
# Name: g-0, dtype: int64

# %%
zero.value_counts().plot.bar()

# %%
zero_maior = dados[dados['g-0'] > 0]
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
zero_maior.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]
